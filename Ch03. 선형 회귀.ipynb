# %% [markdown]
# ## 1) 선형 회귀

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
print(x_train)
print(x_train.shape)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])
# torch.Size([3, 1])

# %%
print(y_train)
print(y_train.shape)
# Out:
# tensor([[2.],
#         [4.],
#         [6.]])
# torch.Size([3, 1])

# %%
W = torch.zeros(1, requires_grad=True)
print(W)
# Out:
# tensor([0.], requires_grad=True)

# %%
b = torch.zeros(1, requires_grad=True)
print(b)
# Out:
# tensor([0.], requires_grad=True)

# %%
hypothesis = x_train * W + b
print(hypothesis)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)

# %%
cost = torch.mean((hypothesis - y_train)**2)
print(cost)
# Out:
# tensor(18.6667, grad_fn=<MeanBackward0>)

# %%
optimizer = optim.SGD([W, b], lr=0.01)
# 학습 대상인 W와 b가 SGD의 입력이 됨.

# %%
optimizer.zero_grad()
cost.backward()
optimizer.step()
#하강법 최적화 함수 opimizer의 .step() 함수를 호출하여 
#인수로 들어갔던 W와 b에서 리턴되는 변수들의 기울기에 학습률(learining rate) 0.01을 
#곱하여 빼줌으로서 업데이트합니다.

# %%
# 데이터
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# 모델 초기화
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# optimizer 설정
optimizer = optim.SGD([W, b], lr=0.01)

num_epochs = 1999
for epoch in range(num_epochs + 1):
  # H(x) 계산
  hypothesis = x_train * W + b

  # cost 계산
  cost = torch.mean((hypothesis - y_train) ** 2)

  # cost로 H(x) 개선
  optimizer.zero_grad() # 미분을 통해 얻은 기울기를 0으로 초기화합니다.
  cost.backward() # 비용 함수를 미분하여 gradient 계산
  optimizer.step() #위 backward를 통해 x - x*lr 로 경사하강법 실행
  #경사 하강법은 비용 함수를 미분하여 이 함수의 기울기(gradient)를 구해서 비용이 최소화 되는 방향을 찾아내는 알고리즘

  # 100번마다 로그 출력
  if epoch % 100 == 0:
      print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
          epoch, num_epochs, W.item(), b.item(), cost.item()
      ))
# Out:
# Epoch    0/1999 W: 0.187, b: 0.080 Cost: 18.666666
# Epoch  100/1999 W: 1.746, b: 0.578 Cost: 0.048171
# Epoch  200/1999 W: 1.800, b: 0.454 Cost: 0.029767
# Epoch  300/1999 W: 1.843, b: 0.357 Cost: 0.018394
# Epoch  400/1999 W: 1.876, b: 0.281 Cost: 0.011366
# Epoch  500/1999 W: 1.903, b: 0.221 Cost: 0.007024
# Epoch  600/1999 W: 1.924, b: 0.174 Cost: 0.004340
# Epoch  700/1999 W: 1.940, b: 0.136 Cost: 0.002682
# Epoch  800/1999 W: 1.953, b: 0.107 Cost: 0.001657
# Epoch  900/1999 W: 1.963, b: 0.084 Cost: 0.001024
# Epoch 1000/1999 W: 1.971, b: 0.066 Cost: 0.000633
# Epoch 1100/1999 W: 1.977, b: 0.052 Cost: 0.000391
# Epoch 1200/1999 W: 1.982, b: 0.041 Cost: 0.000242
# Epoch 1300/1999 W: 1.986, b: 0.032 Cost: 0.000149
# Epoch 1400/1999 W: 1.989, b: 0.025 Cost: 0.000092
# Epoch 1500/1999 W: 1.991, b: 0.020 Cost: 0.000057
# Epoch 1600/1999 W: 1.993, b: 0.016 Cost: 0.000035
# Epoch 1700/1999 W: 1.995, b: 0.012 Cost: 0.000022
# Epoch 1800/1999 W: 1.996, b: 0.010 Cost: 0.000013
# Epoch 1900/1999 W: 1.997, b: 0.008 Cost: 0.000008

# %%
import torch
w = torch.tensor(2.0, requires_grad=True)

nb_epochs = 20
for epoch in range(nb_epochs + 1):

  z = 2*w

  z.backward()
  print('수식을 w로 미분한 값 : {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값 : 2.0
# 수식을 w로 미분한 값 : 4.0
# 수식을 w로 미분한 값 : 6.0
# 수식을 w로 미분한 값 : 8.0
# 수식을 w로 미분한 값 : 10.0
# 수식을 w로 미분한 값 : 12.0
# 수식을 w로 미분한 값 : 14.0
# 수식을 w로 미분한 값 : 16.0
# 수식을 w로 미분한 값 : 18.0
# 수식을 w로 미분한 값 : 20.0
# 수식을 w로 미분한 값 : 22.0
# 수식을 w로 미분한 값 : 24.0
# 수식을 w로 미분한 값 : 26.0
# 수식을 w로 미분한 값 : 28.0
# 수식을 w로 미분한 값 : 30.0
# 수식을 w로 미분한 값 : 32.0
# 수식을 w로 미분한 값 : 34.0
# 수식을 w로 미분한 값 : 36.0
# 수식을 w로 미분한 값 : 38.0
# 수식을 w로 미분한 값 : 40.0
# 수식을 w로 미분한 값 : 42.0

# %% [markdown]
# ## 2) 자동 미분

# %%
import torch

# %%
w = torch.tensor(2.0, requires_grad=True)

# %%
y = w**2
z = 2*y + 5

# %%
z.backward()

# %%
print('수식을 w로 미분한 값 : {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값 : 8.0

# %% [markdown]
# ## 3) 다중 선형 회귀

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
torch.manual_seed(1)

# %%
x1_train = torch.FloatTensor([[73], [93], [89], [96], [73]])
x2_train = torch.FloatTensor([[80], [88], [91], [98], [66]])
x3_train = torch.FloatTensor([[75], [93], [90], [100], [70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
w1 = torch.zeros(1, requires_grad=True)
w2 = torch.zeros(1, requires_grad=True)
w3 = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
optimizer = optim.SGD([w1, w2, w3, b], lr=1e-5)
num_epochs = 1000

for epoch in range(num_epochs + 1):
   hypothesis = x1_train * w1 + x2_train * w2 + x3_train * w3 + b
   cost = torch.mean((hypothesis - y_train)**2)

   optimizer.zero_grad()
   cost.backward()
   optimizer.step()

   if epoch % 100 == 0:
     print('Epoch {:4d}/{} w1: {:.3f} w2: {:.3f} w3: {:.3f} b: {:.3f} Cost: {:.6f}'.format(
          epoch, num_epochs, w1.item(), w2.item(), w3.item(), b.item(), cost.item()
      ))
# Out:
# Epoch    0/1000 w1: 0.294 w2: 0.294 w3: 0.297 b: 0.003 Cost: 29661.800781
# Epoch  100/1000 w1: 0.674 w2: 0.661 w3: 0.676 b: 0.008 Cost: 1.563628
# Epoch  200/1000 w1: 0.679 w2: 0.655 w3: 0.677 b: 0.008 Cost: 1.497595
# Epoch  300/1000 w1: 0.684 w2: 0.649 w3: 0.677 b: 0.008 Cost: 1.435044
# Epoch  400/1000 w1: 0.689 w2: 0.643 w3: 0.678 b: 0.008 Cost: 1.375726
# Epoch  500/1000 w1: 0.694 w2: 0.638 w3: 0.678 b: 0.009 Cost: 1.319507
# Epoch  600/1000 w1: 0.699 w2: 0.633 w3: 0.679 b: 0.009 Cost: 1.266222
# Epoch  700/1000 w1: 0.704 w2: 0.627 w3: 0.679 b: 0.009 Cost: 1.215703
# Epoch  800/1000 w1: 0.709 w2: 0.622 w3: 0.679 b: 0.009 Cost: 1.167810
# Epoch  900/1000 w1: 0.713 w2: 0.617 w3: 0.680 b: 0.009 Cost: 1.122429
# Epoch 1000/1000 w1: 0.718 w2: 0.613 w3: 0.680 b: 0.009 Cost: 1.079390

# %%
x_train  =  torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  80], 
                               [96,  98,  100],   
                               [73,  66,  70]])  
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
print(x_train.shape)
print(y_train.shape)
print(x_train)
print(y_train)
# Out:
# torch.Size([5, 3])
# torch.Size([5, 1])
# tensor([[ 73.,  80.,  75.],
#         [ 93.,  88.,  93.],
#         [ 89.,  91.,  80.],
#         [ 96.,  98., 100.],
#         [ 73.,  66.,  70.]])
# tensor([[152.],
#         [185.],
#         [180.],
#         [196.],
#         [142.]])

# %%
w = torch.zeros((3,1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)

# %%
hypothesis = x_train.matmul(w) + b

# %%
optimizer = optim.SGD([w, b], lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):

    # H(x) 계산
    # 편향 b는 브로드 캐스팅되어 각 샘플에 더해집니다.
    hypothesis = x_train.matmul(w) + b

    # cost 계산
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} hypothesis: {} Cost: {:.6f}'.format(
        epoch, nb_epochs, hypothesis.squeeze().detach(), cost.item()
    ))
# Out:
# Epoch    0/20 hypothesis: tensor([0., 0., 0., 0., 0.]) Cost: 29661.800781
# Epoch    1/20 hypothesis: tensor([66.7178, 80.1701, 76.1025, 86.0194, 61.1565]) Cost: 9537.694336
# Epoch    2/20 hypothesis: tensor([104.5421, 125.6208, 119.2478, 134.7862,  95.8280]) Cost: 3069.590088
# Epoch    3/20 hypothesis: tensor([125.9858, 151.3882, 143.7087, 162.4333, 115.4844]) Cost: 990.670288
# Epoch    4/20 hypothesis: tensor([138.1429, 165.9963, 157.5768, 178.1071, 126.6283]) Cost: 322.481873
# Epoch    5/20 hypothesis: tensor([145.0350, 174.2780, 165.4395, 186.9928, 132.9461]) Cost: 107.717064
# Epoch    6/20 hypothesis: tensor([148.9423, 178.9730, 169.8976, 192.0301, 136.5279]) Cost: 38.687496
# Epoch    7/20 hypothesis: tensor([151.1574, 181.6346, 172.4254, 194.8856, 138.5585]) Cost: 16.499043
# Epoch    8/20 hypothesis: tensor([152.4131, 183.1435, 173.8590, 196.5043, 139.7097]) Cost: 9.365656
# Epoch    9/20 hypothesis: tensor([153.1250, 183.9988, 174.6723, 197.4217, 140.3625]) Cost: 7.071114
# Epoch   10/20 hypothesis: tensor([153.5285, 184.4835, 175.1338, 197.9415, 140.7325]) Cost: 6.331847
# Epoch   11/20 hypothesis: tensor([153.7572, 184.7582, 175.3958, 198.2360, 140.9424]) Cost: 6.092532
# Epoch   12/20 hypothesis: tensor([153.8868, 184.9138, 175.5449, 198.4026, 141.0613]) Cost: 6.013817
# Epoch   13/20 hypothesis: tensor([153.9602, 185.0019, 175.6299, 198.4969, 141.1288]) Cost: 5.986785
# Epoch   14/20 hypothesis: tensor([154.0017, 185.0517, 175.6785, 198.5500, 141.1671]) Cost: 5.976325
# Epoch   15/20 hypothesis: tensor([154.0252, 185.0798, 175.7065, 198.5800, 141.1888]) Cost: 5.971208
# Epoch   16/20 hypothesis: tensor([154.0385, 185.0956, 175.7229, 198.5966, 141.2012]) Cost: 5.967835
# Epoch   17/20 hypothesis: tensor([154.0459, 185.1045, 175.7326, 198.6059, 141.2082]) Cost: 5.964969
# Epoch   18/20 hypothesis: tensor([154.0501, 185.1094, 175.7386, 198.6108, 141.2122]) Cost: 5.962291
# Epoch   19/20 hypothesis: tensor([154.0524, 185.1120, 175.7424, 198.6134, 141.2145]) Cost: 5.959664
# Epoch   20/20 hypothesis: tensor([154.0536, 185.1134, 175.7451, 198.6145, 141.2158]) Cost: 5.957089

# %% [markdown]
# ## 4) nn.Module로 구현하는 선형 회귀
# * 이전 까진 가설함수 / 비용함수를 직접 정의해서 구현했찌만, 파이토치 모델을 이용해서 쉽게 구현이 가능함

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
torch.manual_seed(1)

# %%
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[2],[4],[6]])

# %%
model = nn.Linear(1,1)

# %%
print(list(model.parameters()))
# 첫번째 값이 W / 두번째 값이 b => 두 값모두 랜덤으로 초기화 되어있음.
# Out:
# [Parameter containing:
# tensor([[0.5153]], requires_grad=True), Parameter containing:
# tensor([-0.4414], requires_grad=True)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
num_epochs = 2000
for epoch in range(num_epochs+1):
  pred = model(x_train)
  cost =F.mse_loss(pred, y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  if epoch % 100 == 0:
    print('Epoch {:4d}/{} Cost: {:.6f}'.format(
        epoch, num_epochs, cost.item()
      ))
# Out:
# Epoch    0/2000 Cost: 13.103541
# Epoch  100/2000 Cost: 0.002791
# Epoch  200/2000 Cost: 0.001724
# Epoch  300/2000 Cost: 0.001066
# Epoch  400/2000 Cost: 0.000658
# Epoch  500/2000 Cost: 0.000407
# Epoch  600/2000 Cost: 0.000251
# Epoch  700/2000 Cost: 0.000155
# Epoch  800/2000 Cost: 0.000096
# Epoch  900/2000 Cost: 0.000059
# Epoch 1000/2000 Cost: 0.000037
# Epoch 1100/2000 Cost: 0.000023
# Epoch 1200/2000 Cost: 0.000014
# Epoch 1300/2000 Cost: 0.000009
# Epoch 1400/2000 Cost: 0.000005
# Epoch 1500/2000 Cost: 0.000003
# Epoch 1600/2000 Cost: 0.000002
# Epoch 1700/2000 Cost: 0.000001
# Epoch 1800/2000 Cost: 0.000001
# Epoch 1900/2000 Cost: 0.000000
# Epoch 2000/2000 Cost: 0.000000

# %%
new_var = torch.FloatTensor([4])
pred_y = model(new_var)
print("훈련 후 입력이 4일 때의 예측값 : ", pred_y)
# Out:
# 훈련 후 입력이 4일 때의 예측값 :  tensor([7.9989], grad_fn=<AddBackward0>)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[1.9994]], requires_grad=True), Parameter containing:
# tensor([0.0014], requires_grad=True)]

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
model = nn.Linear(3,1)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[-0.1119,  0.2710, -0.5435]], requires_grad=True), Parameter containing:
# tensor([0.3462], requires_grad=True)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 2000
for epoch in range(nb_epochs+1):

    # H(x) 계산
    prediction = model(x_train)
    # model(x_train)은 model.forward(x_train)와 동일함.

    # cost 계산
    cost = F.mse_loss(prediction, y_train) # <== 파이토치에서 제공하는 평균 제곱 오차 함수

    # cost로 H(x) 개선하는 부분
    # gradient를 0으로 초기화
    optimizer.zero_grad()
    # 비용 함수를 미분하여 gradient 계산
    cost.backward()
    # W와 b를 업데이트
    optimizer.step()

    if epoch % 100 == 0:
    # 100번마다 로그 출력
      print('Epoch {:4d}/{} Cost: {:.6f}'.format(
          epoch, nb_epochs, cost.item()
      ))
# Out:
# Epoch    0/2000 Cost: 42134.707031
# Epoch  100/2000 Cost: 5.960053
# Epoch  200/2000 Cost: 5.654707
# Epoch  300/2000 Cost: 5.365413
# Epoch  400/2000 Cost: 5.091429
# Epoch  500/2000 Cost: 4.831834
# Epoch  600/2000 Cost: 4.585997
# Epoch  700/2000 Cost: 4.353045
# Epoch  800/2000 Cost: 4.132426
# Epoch  900/2000 Cost: 3.923438
# Epoch 1000/2000 Cost: 3.725488
# Epoch 1100/2000 Cost: 3.537972
# Epoch 1200/2000 Cost: 3.360339
# Epoch 1300/2000 Cost: 3.192076
# Epoch 1400/2000 Cost: 3.032686
# Epoch 1500/2000 Cost: 2.881703
# Epoch 1600/2000 Cost: 2.738666
# Epoch 1700/2000 Cost: 2.603199
# Epoch 1800/2000 Cost: 2.474860
# Epoch 1900/2000 Cost: 2.353289
# Epoch 2000/2000 Cost: 2.238115

# %%
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[153.7184]], grad_fn=<AddmmBackward>)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[0.8541, 0.8475, 0.3096]], requires_grad=True), Parameter containing:
# tensor([0.3568], requires_grad=True)]

# %% [markdown]
# ## 5) 클래스로 파이토치 모델 구현하기

# %%
model = nn.Linear(1,1)

# %%
class LinearRegressionModel(nn.Module):
  def __init__(self): # init에서 모델의 구조와 동적을 정의하는 생성자를 정의
    super().__init__() # nn.Module의 속성을 갖게 됨
    self.linear = nn.Linear(1, 1)

  def forward(self, x): # model객체를 데이터와 함께 호출하면 자동으로 실행 됨
    return self.linear(x)

# %%
model = LinearRegressionModel()

# %%
model = nn.Linear(3, 1)

# %%
class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1) # 다중 선형 회귀이므로 input_dim=3, output_dim=1.

    def forward(self, x):
        return self.linear(x)

# %%
model = MultivariateLinearRegressionModel()

# %%
torch.manual_seed(1)

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
class LinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(1, 1)

  def forward(self, x):
    return self.linear(x)

# %%
model = LinearRegressionModel()

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
num_epochs = 2000
for epoch in range(num_epochs + 1):
  pred = model(x_train)
  cost = F.mse_loss(pred, y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  if epoch % 100 == 0:
    print("Epoch {:4d}/{} Cost:{:6f}".format(epoch, num_epochs, cost.item()))
# Out:
# Epoch    0/2000 Cost:18.562185
# Epoch  100/2000 Cost:0.128051
# Epoch  200/2000 Cost:0.079128
# Epoch  300/2000 Cost:0.048896
# Epoch  400/2000 Cost:0.030215
# Epoch  500/2000 Cost:0.018671
# Epoch  600/2000 Cost:0.011538
# Epoch  700/2000 Cost:0.007129
# Epoch  800/2000 Cost:0.004406
# Epoch  900/2000 Cost:0.002722
# Epoch 1000/2000 Cost:0.001682
# Epoch 1100/2000 Cost:0.001040
# Epoch 1200/2000 Cost:0.000642
# Epoch 1300/2000 Cost:0.000397
# Epoch 1400/2000 Cost:0.000245
# Epoch 1500/2000 Cost:0.000152
# Epoch 1600/2000 Cost:0.000094
# Epoch 1700/2000 Cost:0.000058
# Epoch 1800/2000 Cost:0.000036
# Epoch 1900/2000 Cost:0.000022
# Epoch 2000/2000 Cost:0.000014

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1) # 다중 선형 회귀이므로 input_dim=3, output_dim=1.

    def forward(self, x):
        return self.linear(x)

# %%
model = MultivariateLinearRegressionModel()
optimizer = optim.SGD(model.parameters(), lr=1e-5)

# %%
num_epochs = 2000
for epoch in range(num_epochs + 1):
  pred = model(x_train)
  cost = F.mse_loss(pred, y_train)

  optimizer.zero_grad()
  cost.backward()
  optimizer.step()

  if epoch % 100 == 0:
    print("Epoch {:4d}/{} Cost:{:6f}".format(epoch, num_epochs, cost.item()))
# Out:
# Epoch    0/2000 Cost:11517.784180
# Epoch  100/2000 Cost:1.542943
# Epoch  200/2000 Cost:1.483091
# Epoch  300/2000 Cost:1.426335
# Epoch  400/2000 Cost:1.372504
# Epoch  500/2000 Cost:1.321457
# Epoch  600/2000 Cost:1.273041
# Epoch  700/2000 Cost:1.227105
# Epoch  800/2000 Cost:1.183562
# Epoch  900/2000 Cost:1.142241
# Epoch 1000/2000 Cost:1.103038
# Epoch 1100/2000 Cost:1.065842
# Epoch 1200/2000 Cost:1.030547
# Epoch 1300/2000 Cost:0.997054
# Epoch 1400/2000 Cost:0.965277
# Epoch 1500/2000 Cost:0.935116
# Epoch 1600/2000 Cost:0.906485
# Epoch 1700/2000 Cost:0.879303
# Epoch 1800/2000 Cost:0.853507
# Epoch 1900/2000 Cost:0.829003
# Epoch 2000/2000 Cost:0.805743

# %% [markdown]
# ### 6) 미니 배치와 데이터 로드

# %%
from torch.utils.data import TensorDataset
# TensorDataset은 기본적으로 텐서를 입력으로 받음
from torch.utils.data import DataLoader

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = nn.Linear(3, 1)
optimizer = optim.SGD(model.parameters(), lr=1e-5)

# %%
num_epochs = 20
for epoch in range(num_epochs + 1):
  for batch_index, samples in enumerate(dataloader):
    x_train, y_train = samples
    pred = model(x_train)
    cost = F.mse_loss(pred, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, num_epochs, batch_index+1, len(dataloader),
        cost.item()))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 1624.044556
# Epoch    0/20 Batch 2/3 Cost: 689.449280
# Epoch    0/20 Batch 3/3 Cost: 266.390961
# Epoch    1/20 Batch 1/3 Cost: 50.107334
# Epoch    1/20 Batch 2/3 Cost: 11.838553
# Epoch    1/20 Batch 3/3 Cost: 3.348348
# Epoch    2/20 Batch 1/3 Cost: 3.330845
# Epoch    2/20 Batch 2/3 Cost: 0.016328
# Epoch    2/20 Batch 3/3 Cost: 0.885240
# Epoch    3/20 Batch 1/3 Cost: 0.535603
# Epoch    3/20 Batch 2/3 Cost: 0.196102
# Epoch    3/20 Batch 3/3 Cost: 0.758034
# Epoch    4/20 Batch 1/3 Cost: 0.921633
# Epoch    4/20 Batch 2/3 Cost: 0.323351
# Epoch    4/20 Batch 3/3 Cost: 0.098794
# Epoch    5/20 Batch 1/3 Cost: 0.268220
# Epoch    5/20 Batch 2/3 Cost: 0.632139
# Epoch    5/20 Batch 3/3 Cost: 0.134312
# Epoch    6/20 Batch 1/3 Cost: 0.226473
# Epoch    6/20 Batch 2/3 Cost: 0.318450
# Epoch    6/20 Batch 3/3 Cost: 0.878563
# Epoch    7/20 Batch 1/3 Cost: 0.766053
# Epoch    7/20 Batch 2/3 Cost: 0.296484
# Epoch    7/20 Batch 3/3 Cost: 0.629187
# Epoch    8/20 Batch 1/3 Cost: 0.348614
# Epoch    8/20 Batch 2/3 Cost: 0.686728
# Epoch    8/20 Batch 3/3 Cost: 0.022852
# Epoch    9/20 Batch 1/3 Cost: 0.183373
# Epoch    9/20 Batch 2/3 Cost: 0.417592
# Epoch    9/20 Batch 3/3 Cost: 0.808616
# Epoch   10/20 Batch 1/3 Cost: 0.595816
# Epoch   10/20 Batch 2/3 Cost: 0.427116
# Epoch   10/20 Batch 3/3 Cost: 0.019874
# Epoch   11/20 Batch 1/3 Cost: 0.497716
# Epoch   11/20 Batch 2/3 Cost: 0.123597
# Epoch   11/20 Batch 3/3 Cost: 0.760640
# Epoch   12/20 Batch 1/3 Cost: 0.583290
# Epoch   12/20 Batch 2/3 Cost: 0.438291
# Epoch   12/20 Batch 3/3 Cost: 0.202223
# Epoch   13/20 Batch 1/3 Cost: 0.550298
# Epoch   13/20 Batch 2/3 Cost: 0.344347
# Epoch   13/20 Batch 3/3 Cost: 0.469933
# Epoch   14/20 Batch 1/3 Cost: 0.273079
# Epoch   14/20 Batch 2/3 Cost: 0.467444
# Epoch   14/20 Batch 3/3 Cost: 0.765118
# Epoch   15/20 Batch 1/3 Cost: 0.439357
# Epoch   15/20 Batch 2/3 Cost: 0.555532
# Epoch   15/20 Batch 3/3 Cost: 0.042534
# Epoch   16/20 Batch 1/3 Cost: 0.243009
# Epoch   16/20 Batch 2/3 Cost: 0.310068
# Epoch   16/20 Batch 3/3 Cost: 1.076451
# Epoch   17/20 Batch 1/3 Cost: 0.579023
# Epoch   17/20 Batch 2/3 Cost: 0.260099
# Epoch   17/20 Batch 3/3 Cost: 0.412299
# Epoch   18/20 Batch 1/3 Cost: 0.427199
# Epoch   18/20 Batch 2/3 Cost: 0.370881
# Epoch   18/20 Batch 3/3 Cost: 0.326615
# Epoch   19/20 Batch 1/3 Cost: 0.269704
# Epoch   19/20 Batch 2/3 Cost: 0.608261
# Epoch   19/20 Batch 3/3 Cost: 0.255863
# Epoch   20/20 Batch 1/3 Cost: 0.237260
# Epoch   20/20 Batch 2/3 Cost: 0.252568
# Epoch   20/20 Batch 3/3 Cost: 0.985193

# %%
new_var = torch.FloatTensor([[73, 80, 75]])
pred = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.3520]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ### 07) 커스텀 데이터셋

# %%
class CustomDataset(torch.utils.data.Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  # 총 데이터의 개수를 리턴
  def __len__(self): 
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx): 
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = torch.nn.Linear(3, 1)
optimizer = optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 48189.210938
# Epoch    0/20 Batch 2/3 Cost: 6344.856445
# Epoch    0/20 Batch 3/3 Cost: 4219.934082
# Epoch    1/20 Batch 1/3 Cost: 1232.357422
# Epoch    1/20 Batch 2/3 Cost: 211.230530
# Epoch    1/20 Batch 3/3 Cost: 94.851654
# Epoch    2/20 Batch 1/3 Cost: 35.020794
# Epoch    2/20 Batch 2/3 Cost: 12.516342
# Epoch    2/20 Batch 3/3 Cost: 1.705835
# Epoch    3/20 Batch 1/3 Cost: 5.902531
# Epoch    3/20 Batch 2/3 Cost: 1.409709
# Epoch    3/20 Batch 3/3 Cost: 0.105256
# Epoch    4/20 Batch 1/3 Cost: 1.801692
# Epoch    4/20 Batch 2/3 Cost: 5.859886
# Epoch    4/20 Batch 3/3 Cost: 0.013233
# Epoch    5/20 Batch 1/3 Cost: 2.745019
# Epoch    5/20 Batch 2/3 Cost: 1.258049
# Epoch    5/20 Batch 3/3 Cost: 6.271763
# Epoch    6/20 Batch 1/3 Cost: 2.508431
# Epoch    6/20 Batch 2/3 Cost: 4.365737
# Epoch    6/20 Batch 3/3 Cost: 0.000443
# Epoch    7/20 Batch 1/3 Cost: 0.327389
# Epoch    7/20 Batch 2/3 Cost: 3.066322
# Epoch    7/20 Batch 3/3 Cost: 8.057867
# Epoch    8/20 Batch 1/3 Cost: 2.089079
# Epoch    8/20 Batch 2/3 Cost: 5.262801
# Epoch    8/20 Batch 3/3 Cost: 1.357565
# Epoch    9/20 Batch 1/3 Cost: 2.959167
# Epoch    9/20 Batch 2/3 Cost: 0.086751
# Epoch    9/20 Batch 3/3 Cost: 6.703260
# Epoch   10/20 Batch 1/3 Cost: 4.096170
# Epoch   10/20 Batch 2/3 Cost: 3.026555
# Epoch   10/20 Batch 3/3 Cost: 0.042938
# Epoch   11/20 Batch 1/3 Cost: 0.317173
# Epoch   11/20 Batch 2/3 Cost: 5.011995
# Epoch   11/20 Batch 3/3 Cost: 0.891511
# Epoch   12/20 Batch 1/3 Cost: 2.645056
# Epoch   12/20 Batch 2/3 Cost: 3.621207
# Epoch   12/20 Batch 3/3 Cost: 1.202305
# Epoch   13/20 Batch 1/3 Cost: 0.168181
# Epoch   13/20 Batch 2/3 Cost: 3.570641
# Epoch   13/20 Batch 3/3 Cost: 7.711011
# Epoch   14/20 Batch 1/3 Cost: 1.977286
# Epoch   14/20 Batch 2/3 Cost: 5.246264
# Epoch   14/20 Batch 3/3 Cost: 0.306072
# Epoch   15/20 Batch 1/3 Cost: 2.202839
# Epoch   15/20 Batch 2/3 Cost: 3.777711
# Epoch   15/20 Batch 3/3 Cost: 0.001377
# Epoch   16/20 Batch 1/3 Cost: 2.564367
# Epoch   16/20 Batch 2/3 Cost: 3.520997
# Epoch   16/20 Batch 3/3 Cost: 0.641715
# Epoch   17/20 Batch 1/3 Cost: 3.610740
# Epoch   17/20 Batch 2/3 Cost: 0.720868
# Epoch   17/20 Batch 3/3 Cost: 5.283418
# Epoch   18/20 Batch 1/3 Cost: 0.891317
# Epoch   18/20 Batch 2/3 Cost: 5.311595
# Epoch   18/20 Batch 3/3 Cost: 1.423961
# Epoch   19/20 Batch 1/3 Cost: 0.329752
# Epoch   19/20 Batch 2/3 Cost: 2.525001
# Epoch   19/20 Batch 3/3 Cost: 6.960737
# Epoch   20/20 Batch 1/3 Cost: 0.135822
# Epoch   20/20 Batch 2/3 Cost: 5.546263
# Epoch   20/20 Batch 3/3 Cost: 0.635837

# %%
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[151.8098]], grad_fn=<AddmmBackward>)
